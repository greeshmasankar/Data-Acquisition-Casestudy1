# %%
import pandas as pd

# %%
df=pd.read_csv("/content/World Population by country 2024.csv")
df
# Out:
#               Country  Population 2024  Population 2023 Area (km2)  \
# 0               India       1441719852       1428627663         3M
# 1               China       1425178782       1425671352       9.4M
# 2       United States        341814420        339996563       9.1M
# 3           Indonesia        279798049        277534122       1.9M
# 4            Pakistan        245209815        240485658     770.9K
# ..                ...              ...              ...        ...
# 229        Montserrat             4372             4386        102
# 230  Falkland Islands             3803             3791      12.2K
# 231              Niue             1935             1935        261
# 232           Tokelau             1915             1893         10
# 233      Vatican City              526              518        < 1
#
#      Density (/km2)  Growth Rate  World %  World Rank
# 0            485.00       0.0092   0.1801           1
# ...

# %%
df.head()
# Out:
#          Country  Population 2024  Population 2023 Area (km2)  Density (/km2)  \
# 0          India       1441719852       1428627663         3M           485.0
# 1          China       1425178782       1425671352       9.4M           151.0
# 2  United States        341814420        339996563       9.1M            37.0
# 3      Indonesia        279798049        277534122       1.9M           149.0
# 4       Pakistan        245209815        240485658     770.9K           318.0
#
#    Growth Rate  World %  World Rank
# 0       0.0092   0.1801           1
# 1      -0.0003   0.1780           2
# 2       0.0053   0.0427           3
# 3       0.0082   0.0350           4
# 4       0.0196   0.0306           5

# %%
df.describe()
# Out:
#        Population 2024  Population 2023  Density (/km2)  Growth Rate  \
# count     2.340000e+02     2.340000e+02      234.000000   234.000000
# mean      3.468862e+07     3.437442e+07      453.788248     0.009200
# std       1.380750e+08     1.373864e+08     1990.163274     0.011371
# min       5.260000e+02     5.180000e+02        0.140000    -0.030900
# 25%       4.264565e+05     4.225982e+05       39.500000     0.001925
# 50%       5.626359e+06     5.643895e+06       98.500000     0.007950
# 75%       2.392272e+07     2.324537e+07      248.250000     0.015675
# max       1.441720e+09     1.428628e+09    21674.000000     0.048300
#
#           World %  World Rank
# count  228.000000  234.000000
# mean     0.004446  117.500000
# std      0.017459   67.694165
# min      0.000000    1.000000
# 25%      0.000100   59.250000
# 50%      0.000750  117.500000
# 75%      0.003000  175.750000
# max      0.180100  234.000000

# %%
df.shape
# Out:
# (234, 8)

# %%
df.dtypes
# Out:
# Country             object
# Population 2024      int64
# Population 2023      int64
# Area (km2)          object
# Density (/km2)     float64
# Growth Rate        float64
# World %            float64
# World Rank           int64
# dtype: object

# %%
df.isna().sum()
# Out:
# Country            0
# Population 2024    0
# Population 2023    0
# Area (km2)         0
# Density (/km2)     0
# Growth Rate        0
# World %            6
# World Rank         0
# dtype: int64

# %%
df.nunique()
# Out:
# Country            234
# Population 2024    234
# Population 2023    234
# Area (km2)         215
# Density (/km2)     173
# Growth Rate        176
# World %             69
# World Rank         234
# dtype: int64

# %%
df['Population 2024'].mean()
# Out:
# 34688615.31196581

# %%
df['Population 2023'].mean()
# Out:
# 34374424.743589744

# %%
df['Population 2024'].median()
# Out:
# 5626359.0

# %%
df['Population 2024'].std()
# Out:
# 138075008.74835935

# %%
Q1=df['Population 2024'].quantile(0.25)
Q1
# Out:
# 426456.5

# %%
Q3=df['Population 2024'].quantile(0.75)
Q3
# Out:
# 23922722.25

# %%
IQR=Q3-Q1
IQR
# Out:
# 23496265.75

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
lower_bound
# Out:
# -34817942.125

# %%
upper_bound
# Out:
# 59167120.875

# %%
Outliers = df[(df['Population 2024'] < lower_bound) | (df['Population 2024'] > upper_bound)]
Outliers
# Out:
#            Country  Population 2024  Population 2023 Area (km2)  \
# 0            India       1441719852       1428627663         3M
# 1            China       1425178782       1425671352       9.4M
# 2    United States        341814420        339996563       9.1M
# 3        Indonesia        279798049        277534122       1.9M
# 4         Pakistan        245209815        240485658     770.9K
# 5          Nigeria        229152217        223804632     910.8K
# 6           Brazil        217637297        216422446       8.4M
# 7       Bangladesh        174701211        172954319     130.2K
# 8           Russia        143957079        144444359      16.4M
# 9         Ethiopia        129719719        126527060       1.1M
# 10          Mexico        129388467        128455567       1.9M
# 11           Japan        122631432        123294513     364.5K
# 12     Philippines        119106224        117337368     298.2K
# 13           Egypt        114484252        112716598         1M
# ...

# %%
correlation = df['Population 2023'].corr(df['Population 2024'])
correlation
# Out:
# 0.99998203095475

# %%
df.groupby('Population 2023')['Growth Rate'].agg(['mean', 'sum'])
# Out:
#                    mean     sum
# Population 2023
# 518              0.0154  0.0154
# 1893             0.0116  0.0116
# 1935             0.0000  0.0000
# 3791             0.0032  0.0032
# 4386            -0.0032 -0.0032
# ...                 ...     ...
# 240485658        0.0196  0.0196
# 277534122        0.0082  0.0082
# 339996563        0.0053  0.0053
# 1425671352      -0.0003 -0.0003
# 1428627663       0.0092  0.0092
#
# [234 rows x 2 columns]

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Population 2024'}>,
#         <Axes: title={'center': 'Population 2023'}>],
#        [<Axes: title={'center': 'Density (/km2)'}>,
#         <Axes: title={'center': 'Growth Rate'}>],
#        [<Axes: title={'center': 'World %'}>,
#         <Axes: title={'center': 'World Rank'}>]], dtype=object)
